# %% [markdown]
# # 📘 Visualización de la Función
# ## \( f(x,y) = \dfrac{\arctan(x^2 + y^2)}{1 + x^2} \)
#
# En esta sección se muestran las gráficas de la función objetivo utilizada
# para los métodos de optimización en la tarea.
#
# Las visualizaciones incluyen:
#
# - 🎨 Gráfico de superficie 3D
# - 📡 Curvas de nivel (Contour Plot)
# - 🔥 Mapa de calor (Heatmap)
# - 🧩 Región donde se encuentra el mínimo global
#
# Esta función presenta una forma particular debido al término \(1 + x^2\)
# en el denominador, lo que provoca un aplanamiento en dirección del eje X
# cuando \(|x|\) crece. Esto hace interesante la aplicación de métodos de
# optimización.
